# %%
# =========================
# STEP 1: Imports & Config
# =========================

import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import transforms

import numpy as np
import pandas as pd
from pathlib import Path
from PIL import Image
from tqdm import tqdm

# -------------------------
# Device
# -------------------------
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", DEVICE)

# -------------------------
# Paths
# -------------------------
PROJECT_ROOT = Path("..")
DATA_ROOT = PROJECT_ROOT / "DATASET" / "final_balanced_dataset" / "FINAL_BALANCED_DATASET"
FEATURE_ROOT = PROJECT_ROOT / "features"
CNN_FEATURE_DIR = FEATURE_ROOT / "cnn"

CNN_FEATURE_DIR.mkdir(parents=True, exist_ok=True)

print("DATA_ROOT:", DATA_ROOT)
print("CNN_FEATURE_DIR:", CNN_FEATURE_DIR)
# Out:
# Using device: cuda
# DATA_ROOT: ..\DATASET\final_balanced_dataset\FINAL_BALANCED_DATASET
# CNN_FEATURE_DIR: ..\features\cnn

# %%
# =========================
# STEP 2: Build subject-level index
# =========================

records = []

for class_dir in DATA_ROOT.iterdir():
    if not class_dir.is_dir():
        continue

    class_name = class_dir.name  # CN, LMCI, AD

    for subject_dir in class_dir.iterdir():
        if not subject_dir.is_dir():
            continue

        subject_name = subject_dir.name

        # Remove augmentation suffixes (_aug0, _aug1, etc.)
        base_subject_id = subject_name.split("_aug")[0]

        records.append({
            "subject_id": base_subject_id,
            "class": class_name,
            "subject_dir": subject_dir
        })

df = pd.DataFrame(records)

print("Total folders (including augmentations):", len(df))
df.head()
# Out:
# Total folders (including augmentations): 933
#    subject_id class                                        subject_dir
# 0  002_S_0619    AD  ..\DATASET\final_balanced_dataset\FINAL_BALANC...
# 1  002_S_0619    AD  ..\DATASET\final_balanced_dataset\FINAL_BALANC...
# 2  002_S_0619    AD  ..\DATASET\final_balanced_dataset\FINAL_BALANC...
# 3  002_S_0816    AD  ..\DATASET\final_balanced_dataset\FINAL_BALANC...
# 4  002_S_0816    AD  ..\DATASET\final_balanced_dataset\FINAL_BALANC...

# %%
# =========================
# Group by real subject
# =========================

subjects_df = (
    df.groupby(["subject_id", "class"])["subject_dir"]
      .apply(list)
      .reset_index(name="subject_dirs")
)

print("Total REAL subjects:", len(subjects_df))
subjects_df["class"].value_counts()
# Out:
# Total REAL subjects: 639
# class
# LMCI    311
# CN      195
# AD      133
# Name: count, dtype: int64

# %%
subjects_df.head()
# Out:
#    subject_id class                                       subject_dirs
# 0  002_S_0295    CN  [..\DATASET\final_balanced_dataset\FINAL_BALAN...
# 1  002_S_0413    CN  [..\DATASET\final_balanced_dataset\FINAL_BALAN...
# 2  002_S_0619    AD  [..\DATASET\final_balanced_dataset\FINAL_BALAN...
# 3  002_S_0685    CN  [..\DATASET\final_balanced_dataset\FINAL_BALAN...
# 4  002_S_0729  LMCI  [..\DATASET\final_balanced_dataset\FINAL_BALAN...

# %%
# =========================
# STEP 3: Load frozen ResNet50
# =========================

# Load pretrained ResNet50
resnet = models.resnet50(
    weights=models.ResNet50_Weights.IMAGENET1K_V1
)

# Remove the classification layer
resnet.fc = nn.Identity()

# Freeze all parameters
for param in resnet.parameters():
    param.requires_grad = False

# Move to device and set eval mode
resnet = resnet.to(DEVICE)
resnet.eval()

print("✅ ResNet50 loaded as frozen feature extractor")
# Out:
# ✅ ResNet50 loaded as frozen feature extractor

# %%
# Check output feature dimension
dummy = torch.randn(1, 3, 224, 224).to(DEVICE)
with torch.no_grad():
    out = resnet(dummy)

print("Output feature shape:", out.shape)
# Out:
# Output feature shape: torch.Size([1, 2048])

# %%
# =========================
# STEP 4: CNN Image Preprocessing
# =========================

cnn_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )
])

print("✅ CNN preprocessing pipeline defined")
# Out:
# ✅ CNN preprocessing pipeline defined

# %%
# Sanity check transform output
dummy_img = Image.new("RGB", (300, 300))
tensor_img = cnn_transform(dummy_img)

print("Transformed image shape:", tensor_img.shape)
print("Min / Max:", tensor_img.min().item(), tensor_img.max().item())
# Out:
# Transformed image shape: torch.Size([3, 224, 224])
# Min / Max: -2.1179039478302 -1.804444432258606

# %%
# =========================
# Robust deterministic slice sampling
# =========================

def sample_slices(image_paths, num_slices=16):
    """
    Deterministically sample num_slices images from a list of image paths.
    If fewer images are available, repeat the last image.
    If no images are available, return an empty list.
    """
    image_paths = sorted(image_paths)

    if len(image_paths) == 0:
        return []

    if len(image_paths) >= num_slices:
        indices = np.linspace(
            0, len(image_paths) - 1, num_slices
        ).astype(int)
        return [image_paths[i] for i in indices]
    else:
        return image_paths + [image_paths[-1]] * (num_slices - len(image_paths))

# %%
# Check CNN feature directory
print("CNN feature directory exists:", CNN_FEATURE_DIR.exists())

files = list(CNN_FEATURE_DIR.glob("*.npy"))
print("Number of CNN feature files found:", len(files))

if len(files) > 0:
    print("Example feature file:", files[0].name)
# Out:
# CNN feature directory exists: True
# Number of CNN feature files found: 146
# Example feature file: 002_S_0295.npy

# %%
# =========================
# STEP 6: CNN feature extraction per subject
# =========================

all_subject_ids = []
all_labels = []

for idx, row in tqdm(subjects_df.iterrows(), total=len(subjects_df)):
    subject_id = row["subject_id"]
    label = row["class"]
    subject_dirs = row["subject_dirs"]

    save_path = CNN_FEATURE_DIR / f"{subject_id}.npy"

    # Skip if already processed (resume-safe)
    if save_path.exists():
        all_subject_ids.append(subject_id)
        all_labels.append(label)
        continue

    # Collect all slice paths
    image_paths = []
    for d in subject_dirs:
        image_paths.extend(sorted(d.glob("*.png")))

    if len(image_paths) == 0:
        print(f"⚠️ No images found for subject {subject_id}, skipping.")
        continue

    # Sample slices
    sampled_paths = sample_slices(image_paths, num_slices=16)

    images = []
    for p in sampled_paths:
        img = Image.open(p).convert("RGB")
        img = cnn_transform(img)
        images.append(img)

    images = torch.stack(images).to(DEVICE)  # (16, 3, 224, 224)

    # Extract features
    with torch.no_grad():
        feats = resnet(images)               # (16, 2048)
        subject_feat = feats.mean(dim=0)     # (2048,)
        subject_feat = subject_feat.cpu().numpy()

    # Save feature
    np.save(save_path, subject_feat)

    all_subject_ids.append(subject_id)
    all_labels.append(label)

print("✅ CNN feature extraction loop completed")
# Out:
# 100%|██████████| 639/639 [00:00<00:00, 6802.66it/s]
# ⚠️ No images found for subject 002_S_0729, skipping.
# ⚠️ No images found for subject 002_S_0782, skipping.
# ⚠️ No images found for subject 002_S_0954, skipping.
# ⚠️ No images found for subject 002_S_1070, skipping.
# ⚠️ No images found for subject 002_S_1155, skipping.
# ⚠️ No images found for subject 002_S_1268, skipping.
# ⚠️ No images found for subject 003_S_0908, skipping.
# ⚠️ No images found for subject 003_S_1057, skipping.
# ⚠️ No images found for subject 003_S_1122, skipping.
# ⚠️ No images found for subject 005_S_0222, skipping.
# ⚠️ No images found for subject 005_S_0324, skipping.
# ⚠️ No images found for subject 005_S_0448, skipping.
# ⚠️ No images found for subject 005_S_0546, skipping.
# ⚠️ No images found for subject 005_S_1224, skipping.
# ⚠️ No images found for subject 006_S_0675, skipping.
# ⚠️ No images found for subject 006_S_1130, skipping.
# ⚠️ No images found for subject 007_S_0041, skipping.
# ⚠️ No images found for subject 007_S_0101, skipping.
# ⚠️ No images found for subject 007_S_0128, skipping.
# ⚠️ No images found for subject 007_S_0249, skipping.
# ⚠️ No images found for subject 007_S_0293, skipping.
# ⚠️ No images found for subject 007_S_0414, skipping.
# ⚠️ No images found for subject 007_S_0698, skipping.
# ⚠️ No images found for subject 009_S_1030, skipping.
# ⚠️ No images found for subject 010_S_0422, skipping.
# ⚠️ No images found for subject 010_S_0904, skipping.
# ⚠️ No images found for subject 011_S_0168, skipping.
# ⚠️ No images found for subject 011_S_0241, skipping.
# ⚠️ No images found for subject 011_S_0326, skipping.
# ⚠️ No images found for subject 011_S_0362, skipping.
# ⚠️ No images found for subject 011_S_0856, skipping.
# ⚠️ No images found for subject 011_S_0861, skipping.
# ⚠️ No images found for subject 011_S_1080, skipping.
# ⚠️ No images found for subject 011_S_1282, skipping.
# ⚠️ No images found for subject 012_S_0634, skipping.
# ⚠️ No images found for subject 012_S_0932, skipping.
# ⚠️ No images found for subject 012_S_1033, skipping.
# ⚠️ No images found for subject 012_S_1165, skipping.
# ⚠️ No images found for subject 012_S_1292, skipping.
# ⚠️ No images found for subject 012_S_1321, skipping.
# ⚠️ No images found for subject 013_S_0240, skipping.
# ⚠️ No images found for subject 013_S_0325, skipping.
# ⚠️ No images found for subject 013_S_0860, skipping.
# ⚠️ No images found for subject 013_S_1120, skipping.
# ⚠️ No images found for subject 013_S_1186, skipping.
# ⚠️ No images found for subject 013_S_1275, skipping.
# ⚠️ No images found for subject 014_S_0169, skipping.
# ⚠️ No images found for subject 014_S_0557, skipping.
# ⚠️ No images found for subject 014_S_0563, skipping.
# ⚠️ No images found for subject 014_S_0658, skipping.
# ⚠️ No images found for subject 016_S_0354, skipping.
# ⚠️ No images found for subject 016_S_0702, skipping.
# ⚠️ No images found for subject 016_S_1028, skipping.
# ⚠️ No images found for subject 016_S_1117, skipping.
# ⚠️ No images found for subject 016_S_1121, skipping.
# ⚠️ No images found for subject 016_S_1326, skipping.
# ⚠️ No images found for subject 018_S_0057, skipping.
# ⚠️ No images found for subject 018_S_0080, skipping.
# ⚠️ No images found for subject 018_S_0087, skipping.
# ⚠️ No images found for subject 018_S_0142, skipping.
# ⚠️ No images found for subject 018_S_0155, skipping.
# ⚠️ No images found for subject 018_S_0406, skipping.
# ⚠️ No images found for subject 018_S_0450, skipping.
# ⚠️ No images found for subject 021_S_0141, skipping.
# ⚠️ No images found for subject 021_S_0231, skipping.
# ⚠️ No images found for subject 021_S_0273, skipping.
# ⚠️ No images found for subject 021_S_0276, skipping.
# ⚠️ No images found for subject 021_S_0332, skipping.
# ⚠️ No images found for subject 021_S_0424, skipping.
# ⚠️ No images found for subject 021_S_0626, skipping.
# ⚠️ No images found for subject 022_S_0004, skipping.
# ⚠️ No images found for subject 022_S_0544, skipping.
# ⚠️ No images found for subject 022_S_0750, skipping.
# ⚠️ No images found for subject 022_S_0961, skipping.
# ⚠️ No images found for subject 022_S_1351, skipping.
# ⚠️ No images found for subject 022_S_1394, skipping.
# ⚠️ No images found for subject 023_S_0030, skipping.
# ⚠️ No images found for subject 023_S_0042, skipping.
# ⚠️ No images found for subject 023_S_0078, skipping.
# ⚠️ No images found for subject 023_S_0126, skipping.
# ⚠️ No images found for subject 023_S_0217, skipping.
# ⚠️ No images found for subject 023_S_0331, skipping.
# ⚠️ No images found for subject 023_S_0376, skipping.
# ⚠️ No images found for subject 023_S_0388, skipping.
# ⚠️ No images found for subject 023_S_0604, skipping.
# ⚠️ No images found for subject 023_S_0625, skipping.
# ⚠️ No images found for subject 023_S_0855, skipping.
# ⚠️ No images found for subject 023_S_0887, skipping.
# ⚠️ No images found for subject 023_S_1046, skipping.
# ⚠️ No images found for subject 023_S_1126, skipping.
# ⚠️ No images found for subject 023_S_1247, skipping.
# ⚠️ No images found for subject 023_S_1262, skipping.
# ⚠️ No images found for subject 024_S_1307, skipping.
# ⚠️ No images found for subject 024_S_1393, skipping.
# ⚠️ No images found for subject 027_S_0116, skipping.
# ⚠️ No images found for subject 027_S_0179, skipping.
# ⚠️ No images found for subject 027_S_0256, skipping.
# ⚠️ No images found for subject 027_S_0307, skipping.
# ⚠️ No images found for subject 027_S_0408, skipping.
# ⚠️ No images found for subject 027_S_0417, skipping.
# ⚠️ No images found for subject 027_S_0461, skipping.
# ⚠️ No images found for subject 027_S_0485, skipping.
# ⚠️ No images found for subject 027_S_0644, skipping.
# ⚠️ No images found for subject 027_S_0835, skipping.
# ⚠️ No images found for subject 027_S_1045, skipping.
# ⚠️ No images found for subject 027_S_1213, skipping.
# ⚠️ No images found for subject 027_S_1277, skipping.
# ⚠️ No images found for subject 027_S_1387, skipping.
# ⚠️ No images found for subject 029_S_0824, skipping.
# ⚠️ No images found for subject 029_S_0843, skipping.
# ⚠️ No images found for subject 029_S_0845, skipping.
# ⚠️ No images found for subject 029_S_0866, skipping.
# ⚠️ No images found for subject 029_S_0878, skipping.
# ⚠️ No images found for subject 029_S_0914, skipping.
# ⚠️ No images found for subject 029_S_1073, skipping.
# ⚠️ No images found for subject 029_S_1215, skipping.
# ⚠️ No images found for subject 029_S_1318, skipping.
# ⚠️ No images found for subject 029_S_1384, skipping.
# ⚠️ No images found for subject 031_S_0294, skipping.
# ⚠️ No images found for subject 031_S_0351, skipping.
# ⚠️ No images found for subject 031_S_0568, skipping.
# ⚠️ No images found for subject 031_S_0618, skipping.
# ⚠️ No images found for subject 031_S_0830, skipping.
# ⚠️ No images found for subject 031_S_0867, skipping.
# ⚠️ No images found for subject 031_S_1066, skipping.
# ⚠️ No images found for subject 032_S_0095, skipping.
# ⚠️ No images found for subject 032_S_0187, skipping.
# ⚠️ No images found for subject 032_S_0214, skipping.
# ⚠️ No images found for subject 032_S_0479, skipping.
# ⚠️ No images found for subject 032_S_0677, skipping.
# ⚠️ No images found for subject 032_S_0718, skipping.
# ⚠️ No images found for subject 032_S_0978, skipping.
# ⚠️ No images found for subject 032_S_1169, skipping.
# ⚠️ No images found for subject 033_S_0511, skipping.
# ⚠️ No images found for subject 033_S_0513, skipping.
# ⚠️ No images found for subject 033_S_0514, skipping.
# ⚠️ No images found for subject 033_S_0516, skipping.
# ⚠️ No images found for subject 033_S_0567, skipping.
# ⚠️ No images found for subject 033_S_0723, skipping.
# ⚠️ No images found for subject 033_S_0725, skipping.
# ⚠️ No images found for subject 033_S_0734, skipping.
# ⚠️ No images found for subject 033_S_0741, skipping.
# ⚠️ No images found for subject 033_S_0906, skipping.
# ⚠️ No images found for subject 033_S_0920, skipping.
# ⚠️ No images found for subject 033_S_0922, skipping.
# ⚠️ No images found for subject 033_S_0923, skipping.
# ⚠️ No images found for subject 033_S_1016, skipping.
# ⚠️ No images found for subject 033_S_1086, skipping.
# ⚠️ No images found for subject 033_S_1098, skipping.
# ⚠️ No images found for subject 033_S_1116, skipping.
# ⚠️ No images found for subject 033_S_1279, skipping.
# ⚠️ No images found for subject 033_S_1284, skipping.
# ⚠️ No images found for subject 033_S_1309, skipping.
# ⚠️ No images found for subject 035_S_0033, skipping.
# ⚠️ No images found for subject 035_S_0048, skipping.
# ⚠️ No images found for subject 035_S_0156, skipping.
# ⚠️ No images found for subject 035_S_0204, skipping.
# ⚠️ No images found for subject 035_S_0292, skipping.
# ⚠️ No images found for subject 035_S_0555, skipping.
# ⚠️ No images found for subject 035_S_0997, skipping.
# ⚠️ No images found for subject 036_S_0576, skipping.
# ⚠️ No images found for subject 036_S_0656, skipping.
# ⚠️ No images found for subject 036_S_0672, skipping.
# ⚠️ No images found for subject 036_S_0673, skipping.
# ⚠️ No images found for subject 036_S_0748, skipping.
# ⚠️ No images found for subject 036_S_0813, skipping.
# ⚠️ No images found for subject 036_S_0869, skipping.
# ⚠️ No images found for subject 036_S_0945, skipping.
# ⚠️ No images found for subject 036_S_0976, skipping.
# ⚠️ No images found for subject 036_S_1023, skipping.
# ⚠️ No images found for subject 036_S_1135, skipping.
# ⚠️ No images found for subject 036_S_1240, skipping.
# ⚠️ No images found for subject 037_S_0150, skipping.
# ⚠️ No images found for subject 037_S_0303, skipping.
# ⚠️ No images found for subject 037_S_0327, skipping.
# ⚠️ No images found for subject 037_S_0454, skipping.
# ⚠️ No images found for subject 037_S_0467, skipping.
# ⚠️ No images found for subject 037_S_0501, skipping.
# ⚠️ No images found for subject 037_S_0539, skipping.
# ⚠️ No images found for subject 037_S_0552, skipping.
# ⚠️ No images found for subject 037_S_0566, skipping.
# ⚠️ No images found for subject 037_S_0588, skipping.
# ⚠️ No images found for subject 037_S_1078, skipping.
# ⚠️ No images found for subject 037_S_1225, skipping.
# ⚠️ No images found for subject 037_S_1421, skipping.
# ⚠️ No images found for subject 041_S_0125, skipping.
# ⚠️ No images found for subject 041_S_0262, skipping.
# ⚠️ No images found for subject 041_S_0282, skipping.
# ⚠️ No images found for subject 041_S_0314, skipping.
# ⚠️ No images found for subject 041_S_0446, skipping.
# ⚠️ No images found for subject 041_S_0549, skipping.
# ⚠️ No images found for subject 041_S_0598, skipping.
# ⚠️ No images found for subject 041_S_0679, skipping.
# ⚠️ No images found for subject 041_S_0898, skipping.
# ⚠️ No images found for subject 041_S_1002, skipping.
# ⚠️ No images found for subject 041_S_1010, skipping.
# ⚠️ No images found for subject 041_S_1260, skipping.
# ⚠️ No images found for subject 041_S_1412, skipping.
# ⚠️ No images found for subject 041_S_1418, skipping.
# ⚠️ No images found for subject 041_S_1423, skipping.
# ⚠️ No images found for subject 041_S_1425, skipping.
# ⚠️ No images found for subject 051_S_1040, skipping.
# ⚠️ No images found for subject 051_S_1072, skipping.
# ⚠️ No images found for subject 051_S_1123, skipping.
# ⚠️ No images found for subject 051_S_1131, skipping.
# ⚠️ No images found for subject 051_S_1331, skipping.
# ⚠️ No images found for subject 052_S_0671, skipping.
# ⚠️ No images found for subject 052_S_0951, skipping.
# ⚠️ No images found for subject 052_S_0952, skipping.
# ⚠️ No images found for subject 052_S_1054, skipping.
# ⚠️ No images found for subject 052_S_1168, skipping.
# ⚠️ No images found for subject 052_S_1250, skipping.
# ⚠️ No images found for subject 052_S_1251, skipping.
# ⚠️ No images found for subject 052_S_1346, skipping.
# ⚠️ No images found for subject 052_S_1352, skipping.
# ⚠️ No images found for subject 053_S_0389, skipping.
# ⚠️ No images found for subject 053_S_0507, skipping.
# ⚠️ No images found for subject 053_S_0621, skipping.
# ⚠️ No images found for subject 053_S_0919, skipping.
# ⚠️ No images found for subject 057_S_0464, skipping.
# ⚠️ No images found for subject 057_S_0643, skipping.
# ⚠️ No images found for subject 057_S_0779, skipping.
# ⚠️ No images found for subject 057_S_0818, skipping.
# ⚠️ No images found for subject 057_S_0839, skipping.
# ⚠️ No images found for subject 057_S_0934, skipping.
# ⚠️ No images found for subject 057_S_0941, skipping.
# ⚠️ No images found for subject 057_S_1007, skipping.
# ⚠️ No images found for subject 057_S_1217, skipping.
# ⚠️ No images found for subject 057_S_1265, skipping.
# ⚠️ No images found for subject 057_S_1269, skipping.
# ⚠️ No images found for subject 062_S_0578, skipping.
# ⚠️ No images found for subject 062_S_0690, skipping.
# ⚠️ No images found for subject 062_S_0730, skipping.
# ⚠️ No images found for subject 062_S_0768, skipping.
# ⚠️ No images found for subject 062_S_0793, skipping.
# ⚠️ No images found for subject 062_S_1099, skipping.
# ⚠️ No images found for subject 062_S_1182, skipping.
# ⚠️ No images found for subject 062_S_1299, skipping.
# ⚠️ No images found for subject 067_S_0019, skipping.
# ⚠️ No images found for subject 067_S_0029, skipping.
# ⚠️ No images found for subject 067_S_0038, skipping.
# ⚠️ No images found for subject 067_S_0056, skipping.
# ⚠️ No images found for subject 067_S_0059, skipping.
# ⚠️ No images found for subject 067_S_0076, skipping.
# ⚠️ No images found for subject 067_S_0077, skipping.
# ⚠️ No images found for subject 067_S_0098, skipping.
# ⚠️ No images found for subject 067_S_0176, skipping.
# ⚠️ No images found for subject 067_S_0177, skipping.
# ⚠️ No images found for subject 067_S_0257, skipping.
# ⚠️ No images found for subject 067_S_0284, skipping.
# ⚠️ No images found for subject 067_S_0290, skipping.
# ⚠️ No images found for subject 067_S_0336, skipping.
# ⚠️ No images found for subject 067_S_0607, skipping.
# ⚠️ No images found for subject 068_S_0109, skipping.
# ⚠️ No images found for subject 068_S_0127, skipping.
# ⚠️ No images found for subject 068_S_0210, skipping.
# ⚠️ No images found for subject 068_S_0442, skipping.
# ⚠️ No images found for subject 068_S_0473, skipping.
# ⚠️ No images found for subject 068_S_0872, skipping.
# ⚠️ No images found for subject 072_S_0315, skipping.
# ⚠️ No images found for subject 073_S_0089, skipping.
# ⚠️ No images found for subject 073_S_0311, skipping.
# ⚠️ No images found for subject 073_S_0312, skipping.
# ⚠️ No images found for subject 073_S_0386, skipping.
# ⚠️ No images found for subject 073_S_0518, skipping.
# ⚠️ No images found for subject 073_S_0565, skipping.
# ⚠️ No images found for subject 073_S_0746, skipping.
# ⚠️ No images found for subject 073_S_0909, skipping.
# ⚠️ No images found for subject 082_S_0928, skipping.
# ⚠️ No images found for subject 082_S_1119, skipping.
# ⚠️ No images found for subject 082_S_1256, skipping.
# ⚠️ No images found for subject 082_S_1377, skipping.
# ⚠️ No images found for subject 094_S_0434, skipping.
# ⚠️ No images found for subject 094_S_0526, skipping.
# ⚠️ No images found for subject 094_S_0531, skipping.
# ⚠️ No images found for subject 094_S_0692, skipping.
# ⚠️ No images found for subject 094_S_0711, skipping.
# ⚠️ No images found for subject 094_S_0921, skipping.
# ⚠️ No images found for subject 094_S_1027, skipping.
# ⚠️ No images found for subject 094_S_1090, skipping.
# ⚠️ No images found for subject 094_S_1164, skipping.
# ⚠️ No images found for subject 094_S_1188, skipping.
# ⚠️ No images found for subject 094_S_1241, skipping.
# ⚠️ No images found for subject 094_S_1267, skipping.
# ⚠️ No images found for subject 094_S_1293, skipping.
# ⚠️ No images found for subject 094_S_1397, skipping.
# ⚠️ No images found for subject 094_S_1398, skipping.
# ⚠️ No images found for subject 094_S_1402, skipping.
# ⚠️ No images found for subject 094_S_1417, skipping.
# ⚠️ No images found for subject 098_S_0149, skipping.
# ⚠️ No images found for subject 098_S_0160, skipping.
# ⚠️ No images found for subject 098_S_0171, skipping.
# ⚠️ No images found for subject 098_S_0172, skipping.
# ⚠️ No images found for subject 098_S_0269, skipping.
# ⚠️ No images found for subject 098_S_0667, skipping.
# ⚠️ No images found for subject 098_S_0896, skipping.
# ⚠️ No images found for subject 099_S_0040, skipping.
# ⚠️ No images found for subject 099_S_0051, skipping.
# ⚠️ No images found for subject 099_S_0054, skipping.
# ⚠️ No images found for subject 099_S_0060, skipping.
# ⚠️ No images found for subject 099_S_0090, skipping.
# ⚠️ No images found for subject 099_S_0111, skipping.
# ⚠️ No images found for subject 099_S_0291, skipping.
# ⚠️ No images found for subject 099_S_0352, skipping.
# ⚠️ No images found for subject 099_S_0372, skipping.
# ⚠️ No images found for subject 099_S_0470, skipping.
# ⚠️ No images found for subject 099_S_0533, skipping.
# ⚠️ No images found for subject 099_S_0534, skipping.
# ⚠️ No images found for subject 099_S_0551, skipping.
# ⚠️ No images found for subject 099_S_0880, skipping.
# ⚠️ No images found for subject 099_S_1034, skipping.
# ⚠️ No images found for subject 099_S_1144, skipping.
# ⚠️ No images found for subject 100_S_0006, skipping.
# ⚠️ No images found for subject 100_S_0015, skipping.
# ⚠️ No images found for subject 100_S_0035, skipping.
# ⚠️ No images found for subject 100_S_0047, skipping.
# ⚠️ No images found for subject 100_S_0069, skipping.
# ⚠️ No images found for subject 100_S_0190, skipping.
# ⚠️ No images found for subject 100_S_0296, skipping.
# ⚠️ No images found for subject 100_S_0995, skipping.
# ⚠️ No images found for subject 109_S_0950, skipping.
# ⚠️ No images found for subject 109_S_0967, skipping.
# ⚠️ No images found for subject 109_S_1014, skipping.
# ⚠️ No images found for subject 109_S_1114, skipping.
# ⚠️ No images found for subject 109_S_1157, skipping.
# ⚠️ No images found for subject 109_S_1183, skipping.
# ⚠️ No images found for subject 109_S_1343, skipping.
# ⚠️ No images found for subject 114_S_0166, skipping.
# ⚠️ No images found for subject 114_S_0173, skipping.
# ⚠️ No images found for subject 114_S_0374, skipping.
# ⚠️ No images found for subject 114_S_0378, skipping.
# ⚠️ No images found for subject 114_S_0410, skipping.
# ⚠️ No images found for subject 114_S_0416, skipping.
# ⚠️ No images found for subject 114_S_0458, skipping.
# ⚠️ No images found for subject 114_S_0601, skipping.
# ⚠️ No images found for subject 114_S_0979, skipping.
# ⚠️ No images found for subject 114_S_1103, skipping.
# ⚠️ No images found for subject 114_S_1106, skipping.
# ⚠️ No images found for subject 114_S_1118, skipping.
# ⚠️ No images found for subject 116_S_0361, skipping.
# ⚠️ No images found for subject 116_S_0370, skipping.
# ⚠️ No images found for subject 116_S_0382, skipping.
# ⚠️ No images found for subject 116_S_0392, skipping.
# ⚠️ No images found for subject 116_S_0487, skipping.
# ⚠️ No images found for subject 116_S_0648, skipping.
# ⚠️ No images found for subject 116_S_0649, skipping.
# ⚠️ No images found for subject 116_S_0657, skipping.
# ⚠️ No images found for subject 116_S_0752, skipping.
# ⚠️ No images found for subject 116_S_0834, skipping.
# ⚠️ No images found for subject 116_S_1232, skipping.
# ⚠️ No images found for subject 116_S_1243, skipping.
# ⚠️ No images found for subject 116_S_1249, skipping.
# ⚠️ No images found for subject 116_S_1271, skipping.
# ⚠️ No images found for subject 116_S_1315, skipping.
# ⚠️ No images found for subject 121_S_1322, skipping.
# ⚠️ No images found for subject 123_S_0050, skipping.
# ⚠️ No images found for subject 123_S_0072, skipping.
# ⚠️ No images found for subject 123_S_0088, skipping.
# ⚠️ No images found for subject 123_S_0091, skipping.
# ⚠️ No images found for subject 123_S_0094, skipping.
# ⚠️ No images found for subject 123_S_0106, skipping.
# ⚠️ No images found for subject 123_S_0108, skipping.
# ⚠️ No images found for subject 123_S_0113, skipping.
# ⚠️ No images found for subject 123_S_0162, skipping.
# ⚠️ No images found for subject 123_S_0298, skipping.
# ⚠️ No images found for subject 123_S_0390, skipping.
# ⚠️ No images found for subject 123_S_1300, skipping.
# ⚠️ No images found for subject 126_S_0605, skipping.
# ⚠️ No images found for subject 126_S_0606, skipping.
# ⚠️ No images found for subject 126_S_0680, skipping.
# ⚠️ No images found for subject 126_S_0708, skipping.
# ⚠️ No images found for subject 126_S_0709, skipping.
# ⚠️ No images found for subject 126_S_0784, skipping.
# ⚠️ No images found for subject 126_S_0865, skipping.
# ⚠️ No images found for subject 126_S_0891, skipping.
# ⚠️ No images found for subject 126_S_1187, skipping.
# ⚠️ No images found for subject 126_S_1221, skipping.
# ⚠️ No images found for subject 127_S_0112, skipping.
# ⚠️ No images found for subject 127_S_0259, skipping.
# ⚠️ No images found for subject 127_S_0260, skipping.
# ⚠️ No images found for subject 127_S_0393, skipping.
# ⚠️ No images found for subject 127_S_0394, skipping.
# ⚠️ No images found for subject 127_S_0431, skipping.
# ⚠️ No images found for subject 127_S_0622, skipping.
# ⚠️ No images found for subject 127_S_0684, skipping.
# ⚠️ No images found for subject 127_S_0754, skipping.
# ⚠️ No images found for subject 127_S_0844, skipping.
# ⚠️ No images found for subject 127_S_0925, skipping.
# ⚠️ No images found for subject 127_S_1032, skipping.
# ⚠️ No images found for subject 127_S_1140, skipping.
# ⚠️ No images found for subject 127_S_1382, skipping.
# ⚠️ No images found for subject 127_S_1419, skipping.
# ⚠️ No images found for subject 127_S_1427, skipping.
# ⚠️ No images found for subject 128_S_0863, skipping.
# ⚠️ No images found for subject 128_S_0947, skipping.
# ⚠️ No images found for subject 128_S_1043, skipping.
# ⚠️ No images found for subject 128_S_1088, skipping.
# ⚠️ No images found for subject 128_S_1148, skipping.
# ⚠️ No images found for subject 128_S_1242, skipping.
# ⚠️ No images found for subject 128_S_1407, skipping.
# ⚠️ No images found for subject 128_S_1408, skipping.
# ⚠️ No images found for subject 129_S_0778, skipping.
# ⚠️ No images found for subject 129_S_1246, skipping.
# ⚠️ No images found for subject 130_S_0102, skipping.
# ⚠️ No images found for subject 130_S_0232, skipping.
# ⚠️ No images found for subject 130_S_0423, skipping.
# ⚠️ No images found for subject 130_S_0505, skipping.
# ⚠️ No images found for subject 130_S_0783, skipping.
# ⚠️ No images found for subject 130_S_0886, skipping.
# ⚠️ No images found for subject 130_S_0956, skipping.
# ⚠️ No images found for subject 130_S_0969, skipping.
# ⚠️ No images found for subject 130_S_1200, skipping.
# ⚠️ No images found for subject 130_S_1201, skipping.
# ⚠️ No images found for subject 130_S_1290, skipping.
# ⚠️ No images found for subject 130_S_1337, skipping.
# ⚠️ No images found for subject 131_S_0123, skipping.
# ⚠️ No images found for subject 131_S_0384, skipping.
# ⚠️ No images found for subject 131_S_0441, skipping.
# ⚠️ No images found for subject 131_S_0457, skipping.
# ⚠️ No images found for subject 131_S_0497, skipping.
# ⚠️ No images found for subject 131_S_1301, skipping.
# ⚠️ No images found for subject 131_S_1389, skipping.
# ⚠️ No images found for subject 132_S_0987, skipping.
# ⚠️ No images found for subject 133_S_0433, skipping.
# ⚠️ No images found for subject 133_S_0488, skipping.
# ⚠️ No images found for subject 133_S_0525, skipping.
# ⚠️ No images found for subject 133_S_0629, skipping.
# ⚠️ No images found for subject 133_S_0638, skipping.
# ⚠️ No images found for subject 133_S_0727, skipping.
# ⚠️ No images found for subject 133_S_0771, skipping.
# ⚠️ No images found for subject 133_S_0792, skipping.
# ⚠️ No images found for subject 133_S_0912, skipping.
# ⚠️ No images found for subject 133_S_0913, skipping.
# ⚠️ No images found for subject 133_S_1170, skipping.
# ⚠️ No images found for subject 136_S_0086, skipping.
# ⚠️ No images found for subject 136_S_0107, skipping.
# ⚠️ No images found for subject 136_S_0184, skipping.
# ⚠️ No images found for subject 136_S_0186, skipping.
# ⚠️ No images found for subject 136_S_0194, skipping.
# ⚠️ No images found for subject 136_S_0195, skipping.
# ⚠️ No images found for subject 136_S_0196, skipping.
# ⚠️ No images found for subject 136_S_0299, skipping.
# ⚠️ No images found for subject 136_S_0300, skipping.
# ⚠️ No images found for subject 136_S_0426, skipping.
# ⚠️ No images found for subject 136_S_0429, skipping.
# ⚠️ No images found for subject 136_S_0579, skipping.
# ⚠️ No images found for subject 136_S_0695, skipping.
# ⚠️ No images found for subject 136_S_0873, skipping.
# ⚠️ No images found for subject 136_S_0874, skipping.
# ⚠️ No images found for subject 136_S_1227, skipping.
# ⚠️ No images found for subject 137_S_0158, skipping.
# ⚠️ No images found for subject 137_S_0283, skipping.
# ⚠️ No images found for subject 137_S_0301, skipping.
# ⚠️ No images found for subject 137_S_0366, skipping.
# ⚠️ No images found for subject 137_S_0443, skipping.
# ⚠️ No images found for subject 137_S_0459, skipping.
# ⚠️ No images found for subject 137_S_0481, skipping.
# ⚠️ No images found for subject 137_S_0631, skipping.
# ⚠️ No images found for subject 137_S_0668, skipping.
# ⚠️ No images found for subject 137_S_0669, skipping.
# ⚠️ No images found for subject 137_S_0686, skipping.
# ⚠️ No images found for subject 137_S_0722, skipping.
# ⚠️ No images found for subject 137_S_0796, skipping.
# ⚠️ No images found for subject 137_S_0800, skipping.
# ⚠️ No images found for subject 137_S_0825, skipping.
# ⚠️ No images found for subject 137_S_0972, skipping.
# ⚠️ No images found for subject 137_S_0973, skipping.
# ⚠️ No images found for subject 137_S_0994, skipping.
# ⚠️ No images found for subject 137_S_1041, skipping.
# ⚠️ No images found for subject 137_S_1414, skipping.
# ⚠️ No images found for subject 137_S_1426, skipping.
# ⚠️ No images found for subject 141_S_0696, skipping.
# ⚠️ No images found for subject 141_S_0717, skipping.
# ⚠️ No images found for subject 141_S_0726, skipping.
# ⚠️ No images found for subject 141_S_0767, skipping.
# ⚠️ No images found for subject 141_S_0790, skipping.
# ⚠️ No images found for subject 141_S_0810, skipping.
# ⚠️ No images found for subject 141_S_0851, skipping.
# ⚠️ No images found for subject 141_S_0852, skipping.
# ⚠️ No images found for subject 141_S_0853, skipping.
# ⚠️ No images found for subject 141_S_0915, skipping.
# ⚠️ No images found for subject 141_S_0982, skipping.
# ⚠️ No images found for subject 141_S_1004, skipping.
# ⚠️ No images found for subject 141_S_1052, skipping.
# ⚠️ No images found for subject 141_S_1094, skipping.
# ⚠️ No images found for subject 141_S_1137, skipping.
# ⚠️ No images found for subject 141_S_1152, skipping.
# ⚠️ No images found for subject 141_S_1245, skipping.
# ⚠️ No images found for subject 141_S_1255, skipping.
# ⚠️ No images found for subject 941_S_1194, skipping.
# ⚠️ No images found for subject 941_S_1197, skipping.
# ⚠️ No images found for subject 941_S_1202, skipping.
# ⚠️ No images found for subject 941_S_1311, skipping.
# ✅ CNN feature extraction loop completed

# %%
files = list(CNN_FEATURE_DIR.glob("*.npy"))
print("Final CNN feature count:", len(files))
# Out:
# Final CNN feature count: 146

# %%
# =========================
# STEP 7: Save subject labels index
# =========================

labels_df = pd.DataFrame({
    "subject_id": all_subject_ids,
    "label": all_labels
})

labels_path = FEATURE_ROOT / "labels.csv"
labels_df.to_csv(labels_path, index=False)

print("✅ labels.csv saved at:", labels_path)
print("Total labeled subjects:", len(labels_df))
labels_df["label"].value_counts()
# Out:
# ✅ labels.csv saved at: ..\features\labels.csv
# Total labeled subjects: 146
# label
# AD    76
# CN    70
# Name: count, dtype: int64

# %%
import pandas as pd

labels_df = pd.read_csv(FEATURE_ROOT / "labels.csv")
print(labels_df["label"].value_counts())
# Out:
# label
# AD    76
# CN    70
# Name: count, dtype: int64

# %%
# Inspect LMCI folders to see what files they contain
lmci_dirs = subjects_df[subjects_df["class"] == "LMCI"].iloc[0]["subject_dirs"]

for d in lmci_dirs:
    print("\nFolder:", d)
    for f in list(d.iterdir())[:10]:
        print("  ", f.name)
# Out:
# Folder: ..\DATASET\final_balanced_dataset\FINAL_BALANCED_DATASET\LMCI\002_S_0729
#    sagittal_slices

# %%
# Inspect actual slice file extensions in one LMCI subject
lmci_subject = subjects_df[subjects_df["class"] == "LMCI"].iloc[0]
dirs = lmci_subject["subject_dirs"]

extensions = set()

for d in dirs:
    for f in d.rglob("*"):
        if f.is_file():
            extensions.add(f.suffix)

print("Found file extensions:", extensions)
# Out:
# Found file extensions: {'.png'}

# %%
# =========================
# STEP 6: CNN Feature Extraction (FINAL)
# =========================

from tqdm import tqdm

all_subject_ids = []
all_labels = []

print("Starting CNN feature extraction...")

# Ensure feature directory exists (bulletproof)
CNN_FEATURE_DIR.mkdir(parents=True, exist_ok=True)


for idx, row in tqdm(subjects_df.iterrows(), total=len(subjects_df)):

    subject_id = row["subject_id"]
    label = row["class"]
    subject_dirs = row["subject_dirs"]

    save_path = CNN_FEATURE_DIR / f"{subject_id}.npy"

    # -------------------------
    # Resume-safe: skip if already done
    # -------------------------
    if save_path.exists():
        all_subject_ids.append(subject_id)
        all_labels.append(label)
        continue

    # -------------------------
    # Collect ALL slice images (recursive)
    # -------------------------
    image_paths = []
    for d in subject_dirs:
        image_paths.extend(sorted(d.rglob("*.png")))

    # If still no images, skip subject
    if len(image_paths) == 0:
        print(f"⚠️ No valid slices for subject {subject_id}, skipping.")
        continue

    # -------------------------
    # Deterministic slice sampling
    # -------------------------
    sampled_paths = sample_slices(image_paths, num_slices=16)

    if len(sampled_paths) == 0:
        print(f"⚠️ Sampling failed for subject {subject_id}, skipping.")
        continue

    # -------------------------
    # Load & preprocess images
    # -------------------------
    images = []
    for p in sampled_paths:
        img = Image.open(p).convert("RGB")
        img = cnn_transform(img)
        images.append(img)

    images = torch.stack(images).to(DEVICE)   # (16, 3, 224, 224)

    # -------------------------
    # CNN feature extraction
    # -------------------------
    with torch.no_grad():
        feats = resnet(images)               # (16, 2048)
        subject_feat = feats.mean(dim=0)     # (2048,)
        subject_feat = subject_feat.cpu().numpy()

    # -------------------------
    # Save feature
    # -------------------------
    np.save(save_path, subject_feat)

    all_subject_ids.append(subject_id)
    all_labels.append(label)

print("✅ CNN feature extraction completed successfully.")
print("Total subjects processed:", len(all_subject_ids))
# Out:
# Starting CNN feature extraction...
# 100%|██████████| 639/639 [02:36<00:00,  4.07it/s]
# ✅ CNN feature extraction completed successfully.
# Total subjects processed: 639

# %%
# =========================
# STEP 7: Save subject labels index (FINAL)
# =========================

import pandas as pd

labels_df = pd.DataFrame({
    "subject_id": all_subject_ids,
    "label": all_labels
})

labels_path = FEATURE_ROOT / "labels.csv"
labels_df.to_csv(labels_path, index=False)

print("✅ labels.csv saved at:", labels_path)
print("Total labeled subjects:", len(labels_df))
print("\nClass distribution:")
print(labels_df["label"].value_counts())
# Out:
# ✅ labels.csv saved at: ..\features\labels.csv
# Total labeled subjects: 639
#
# Class distribution:
# label
# LMCI    311
# CN      195
# AD      133
# Name: count, dtype: int64

# %%
# Final verification of CNN features and labels

import pandas as pd

cnn_files = list(CNN_FEATURE_DIR.glob("*.npy"))
print("Total CNN feature files:", len(cnn_files))

labels_df = pd.read_csv(FEATURE_ROOT / "labels.csv")
print("\nClass distribution:")
print(labels_df["label"].value_counts())
# Out:
# Total CNN feature files: 639
#
# Class distribution:
# label
# LMCI    311
# CN      195
# AD      133
# Name: count, dtype: int64
